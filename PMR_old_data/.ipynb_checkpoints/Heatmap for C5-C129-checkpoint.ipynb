# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
file = glob.glob("./C5-C129/*.csv")
file
# Out:
# ['./C5-C129/C38.csv',
#  './C5-C129/C10.csv',
#  './C5-C129/C11.csv',
#  './C5-C129/C39.csv',
#  './C5-C129/C13.csv',
#  './C5-C129/C12.csv',
#  './C5-C129/C5.csv',
#  './C5-C129/C16.csv',
#  './C5-C129/C17.csv',
#  './C5-C129/C6.csv',
#  './C5-C129/C15.csv',
#  './C5-C129/C29.csv',
#  './C5-C129/C28.csv',
#  './C5-C129/C14.csv',
#  './C5-C129/C113.csv',
#  './C5-C129/C107.csv',
#  './C5-C129/C98.csv',
#  './C5-C129/C73.csv',
#  './C5-C129/C67.csv',
#  './C5-C129/C66.csv',
#  './C5-C129/C72.csv',
#  './C5-C129/C99.csv',
#  './C5-C129/C106.csv',
#  './C5-C129/C112.csv',
#  './C5-C129/C104.csv',
#  './C5-C129/C110.csv',
#  './C5-C129/C58.csv',
#  './C5-C129/C64.csv',
#  './C5-C129/C70.csv',
#  './C5-C129/C71.csv',
#  './C5-C129/C65.csv',
#  './C5-C129/C59.csv',
#  './C5-C129/C111.csv',
#  './C5-C129/C105.csv',
#  './C5-C129/C129.csv',
#  './C5-C129/C101.csv',
#  './C5-C129/C115.csv',
#  './C5-C129/C61.csv',
#  './C5-C129/C75.csv',
#  './C5-C129/C49.csv',
#  './C5-C129/C48.csv',
# ...
